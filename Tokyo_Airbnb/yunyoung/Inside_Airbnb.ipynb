# %% [markdown]
# ## 에어비앤비 데이터 정리
# ### Inside_Airbnb 데이터 정보 : <a href = 'https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit#gid=150111846'>Inside Airbnb Data Dictionary</a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 데이터 살펴보기

# %% [markdown]
# #### reviews.csv.gz

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.2-py3-none-any.whl (153 kB)
#                                               0.0/153.0 kB ? eta -:--:--
#      -----------------------                 92.2/153.0 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 153.0/153.0 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.2
# WARNING: Ignoring invalid distribution -ip (c:\users\yun\miniconda3\envs\ds_study\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\yun\miniconda3\envs\ds_study\lib\site-packages)

# %%
# colab
# base_path = '/content/drive/MyDrive/Colab Notebooks/Data Project/Data/'

#vscode 
base_path = '../data/'
review_gz = pd.read_csv(base_path+'reviews.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
review_gz.head()
# Out:
#    listing_id      id        date  reviewer_id  reviewer_name  \
# 0      197677  554285  2011-09-21      1002142          Pablo
# 1      197677  627651  2011-10-14      1031940  Ana & Ricardo
# 2      197677  733040  2011-11-21      1097040         Samuel
# 3      197677  755841  2011-11-30      1183674           Lisa
# 4      197677  852938  2012-01-09      1538004         Langan
#
#                                             comments
# 0  Couldn’t get any better!\r<br/>\r<br/>The apar...
# 1  The apartment is bigger than it looks in the p...
# 2  The appartement is perfect for a couple! It is...
# 3  We had a terrific stay at Yoshimi and Marek's ...
# 4  We loved our stay at the Oshiage Holiday Apart...

# %% [markdown]
# #### neighbourhoods.geojson

# %%
import json, pandas as pd

# %%
with open(base_path+'neighbourhoods.geojson') as f:
    json_f = json.loads(f.read()) # json 라이브러리 이용

df = pd.DataFrame(json_f)
df = pd.read_json(base_path+'neighbourhoods.geojson') # pd.read_json 이용

# %%
df.head()
# Out:
#                 type                                           features
# 0  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 1  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 2  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 3  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 4  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...

# %% [markdown]
# #### reviews.csv

# %%
review = pd.read_csv(base_path+'reviews.csv')
review
# Out:
#                 listing_id        date
# 0                   197677  2011-09-21
# 1                   197677  2011-10-14
# 2                   197677  2011-11-21
# 3                   197677  2011-11-30
# 4                   197677  2012-01-09
# ...                    ...         ...
# 407707  915528151021700798  2023-06-26
# 407708  918757671248742571  2023-06-27
# 407709  913660262216995906  2023-06-21
# 407710  914001948186290663  2023-06-25
# 407711  922833637376956356  2023-06-29
#
# [407712 rows x 2 columns]

# %% [markdown]
# #### neighbourhoods.csv

# %%
neighbor = pd.read_csv(base_path+'neighbourhoods.csv')
neighbor
# Out:
#     neighbourhood_group   neighbourhood
# 0                   NaN       Adachi Ku
# 1                   NaN     Akiruno Shi
# 2                   NaN    Akishima Shi
# 3                   NaN  Aogashima Mura
# 4                   NaN      Arakawa Ku
# ..                  ...             ...
# 57                  NaN   Tachikawa Shi
# 58                  NaN        Taito Ku
# 59                  NaN        Tama Shi
# 60                  NaN      Toshima Ku
# 61                  NaN    Toshima Mura
#
# [62 rows x 2 columns]

# %% [markdown]
# #### listings.csv.gz

# %%
listing_gz = pd.read_csv(base_path+'listings.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
listing_gz.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   197677   https://www.airbnb.com/rooms/197677  20230629055629   2023-06-29
# 1   776070   https://www.airbnb.com/rooms/776070  20230629055629   2023-06-29
# 2   905944   https://www.airbnb.com/rooms/905944  20230629055629   2023-06-29
# 3  1016831  https://www.airbnb.com/rooms/1016831  20230629055629   2023-06-29
# 4  1196177  https://www.airbnb.com/rooms/1196177  20230629055629   2023-06-29
#
#         source                                               name  \
# 0  city scrape  Rental unit in Sumida · ★4.78 · 1 bedroom · 2 ...
# 1  city scrape  Home in Kita-ku · ★4.98 · 1 bedroom · 1 bed · ...
# 2  city scrape  Rental unit in Shibuya · ★4.76 · 2 bedrooms · ...
# 3  city scrape  Home in Setagaya · ★4.94 · 1 bedroom · 2 beds ...
# 4  city scrape  Home in 足立区 · ★4.71 · 1 bedroom · 1.5 shared b...
#
#                                          description  \
# 0  <b>The space</b><br />We are happy to welcome ...
# 1  We have been in airbnb since 2011 and it has g...
# 2  NEWLY RENOVATED property entirely for you & yo...
# 3  Hi there, I am Wakana and I live with my two f...
# 4  Ｓtay with host.We can help your travel.<br />B...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  We love Nishinippori because is nearer to Toky...
# 2  Hatagaya is a great neighborhood located 4 min...
# 3  The location is walkable distance to famous Sh...
# 4  There are shopping mall near Senjuohashi stati...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/38437056/d27f...   964081  ...
# 1  https://a0.muscache.com/pictures/efd9f039-dbd2...   801494  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...  4847803  ...
# 3  https://a0.muscache.com/pictures/airflow/Hosti...  5596383  ...
# 4  https://a0.muscache.com/pictures/72890882/05ec...  5686404  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.83                   4.53                4.79
# 1                        4.98                   4.83                4.91
# 2                        4.90                   4.77                4.77
# 3                        4.98                   4.92                4.89
# 4                        4.88                   4.67                4.75
#
#                                              license instant_bookable  \
# 0                                         M130003350                f
# 1                                                NaN                f
# 2  Hotels and Inns Business Act | 渋谷区保健所長 | 31渋健生...                t
# 3                                                NaN                f
# 4                                                NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              1                                           0
# 2                              5                                           5
# 3                              1                                           0
# 4                              1                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.21
# 1                                           0              1.89
# 2                                           0              1.49
# 3                                           0              1.96
# 4                                           0              0.79
#
# [5 rows x 75 columns]

# %% [markdown]
# #### listings.csv

# %%
listings = pd.read_csv(base_path+'listings.csv')
listings.tail()
# Out:
#                        id                                               name  \
# 11172  922873759575839340  Rental unit in Shinjuku City · ★New · 1 bedroo...
# 11173  922998222764343634  Rental unit in Shinjuku City · ★New · 1 bedroo...
# 11174  923008447744339896  Rental unit in Shinjuku City · ★New · 1 bedroo...
# 11175  923011844205437846  Rental unit in Shinjuku City · ★New · 3 bedroo...
# 11176  923132709196905769  Rental unit in Shinjuku City · ★New · 1 bedroo...
#
#          host_id host_name  neighbourhood_group neighbourhood   latitude  \
# 11172  294322772        鈴木                  NaN   Shinjuku Ku  35.697773
# 11173  518343589    Yingzi                  NaN   Shinjuku Ku  35.698980
# 11174  518343589    Yingzi                  NaN   Shinjuku Ku  35.700080
# 11175  518343589    Yingzi                  NaN   Shinjuku Ku  35.699860
# 11176  518119710        伊藤                  NaN   Shinjuku Ku  35.698123
#
#         longitude        room_type  price  minimum_nights  number_of_reviews  \
# 11172  139.706543  Entire home/apt  12000               2                  0
# 11173  139.694320  Entire home/apt  16000               2                  0
# 11174  139.695020  Entire home/apt  16000               2                  0
# 11175  139.693340  Entire home/apt  40000               2                  0
# 11176  139.706093  Entire home/apt  15000               2                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 11172         NaN                NaN                              10
# 11173         NaN                NaN                              12
# 11174         NaN                NaN                              12
# 11175         NaN                NaN                              12
# 11176         NaN                NaN                               3
#
#        availability_365  number_of_reviews_ltm  \
# 11172               113                      0
# 11173               254                      0
# 11174               261                      0
# 11175               194                      0
# 11176               350                      0
#
#                                                  license
# 11172  Hotels and Inns Business Act | 新宿区保健所 | 31新保衛環...
# 11173  Hotels and Inns Business Act | 新宿区保健所 | 2新保衛環第94号
# 11174  Hotels and Inns Business Act | 新宿区保健所 | 2新保衛環第94号
# 11175  Hotels and Inns Business Act | 新宿区保健所 | 2新保衛環第94号
# 11176  Hotels and Inns Business Act | 新宿区保健所 | 31新保衛環...

# %% [markdown]
# #### calendar.csv.gz

# %%
calendar_gz = pd.read_csv(base_path+'calendar.csv.gz', compression='gzip', header=0, sep=',', quotechar='"')
calendar_gz.head()
# Out:
#    listing_id        date available       price adjusted_price  \
# 0      197677  2023-06-29         f  $11,000.00     $11,000.00
# 1      197677  2023-06-30         f  $11,000.00     $11,000.00
# 2      197677  2023-07-01         f  $11,000.00     $11,000.00
# 3      197677  2023-07-02         f  $11,000.00     $11,000.00
# 4      197677  2023-07-03         f  $11,000.00     $11,000.00
#
#    minimum_nights  maximum_nights
# 0             3.0          1125.0
# 1             3.0          1125.0
# 2             3.0          1125.0
# 3             3.0          1125.0
# 4             3.0          1125.0

# %%
listing_gz.iloc[0,:]
# Out:
# id                                                                           197677
# listing_url                                     https://www.airbnb.com/rooms/197677
# scrape_id                                                            20230629055629
# last_scraped                                                             2023-06-29
# source                                                                  city scrape
#                                                                ...
# calculated_host_listings_count                                                    1
# calculated_host_listings_count_entire_homes                                       1
# calculated_host_listings_count_private_rooms                                      0
# calculated_host_listings_count_shared_rooms                                       0
# reviews_per_month                                                              1.21
# Name: 0, Length: 75, dtype: object

# %% [markdown]
# ## 에어비앤비 주요 지역 탐색

# %% [markdown]
# ### 주요지역 추출에 도움이 될만한 컬럼 선택
#
# - listing_gz :  latitude, longitude, neighbourhood_cleansed
#
# - listings :  latitude, longitude, **neighbourhood**

# %%
listing_gz.loc[0,['latitude', 'longitude', 'neighbourhood', 'neighbourhood_cleansed']]
# Out:
# latitude                   35.71707
# longitude                 139.82608
# neighbourhood                   NaN
# neighbourhood_cleansed    Sumida Ku
# Name: 0, dtype: object

# %%
listings.loc[0,['latitude', 'longitude', 'neighbourhood']]
# Out:
# latitude          35.71707
# longitude        139.82608
# neighbourhood    Sumida Ku
# Name: 0, dtype: object

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11177 entries, 0 to 11176
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              11177 non-null  int64
#  1   name                            11177 non-null  object
#  2   host_id                         11177 non-null  int64
#  3   host_name                       11177 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   11177 non-null  object
#  6   latitude                        11177 non-null  float64
#  7   longitude                       11177 non-null  float64
#  8   room_type                       11177 non-null  object
#  9   price                           11177 non-null  int64
#  10  minimum_nights                  11177 non-null  int64
#  11  number_of_reviews               11177 non-null  int64
#  12  last_review                     9925 non-null   object
#  13  reviews_per_month               9925 non-null   float64
#  14  calculated_host_listings_count  11177 non-null  int64
#  15  availability_365                11177 non-null  int64
#  16  number_of_reviews_ltm           11177 non-null  int64
#  17  license                         10237 non-null  object
# dtypes: float64(4), int64(8), object(6)
# memory usage: 1.5+ MB

# %%
print(len(listings['neighbourhood'].unique()))
listings['neighbourhood'].unique()
# Out:
# 46
# array(['Sumida Ku', 'Kita Ku', 'Edogawa Ku', 'Shibuya Ku', 'Arakawa Ku',
#        'Setagaya Ku', 'Machida Shi', 'Adachi Ku', 'Toshima Ku',
#        'Katsushika Ku', 'Shinjuku Ku', 'Meguro Ku', 'Suginami Ku',
#        'Ota Ku', 'Higashimurayama Shi', 'Shinagawa Ku', 'Taito Ku',
#        'Nakano Ku', 'Koto Ku', 'Kokubunji Shi', 'Akishima Shi',
#        'Bunkyo Ku', 'Hino Shi', 'Mitaka Shi', 'Itabashi Ku', 'Minato Ku',
#        'Hachioji Shi', 'Nerima Ku', 'Fuchu Shi', 'Chuo Ku', 'Kodaira Shi',
#        'Tama Shi', 'Komae Shi', 'Chofu Shi', 'Chiyoda Ku', 'Akiruno Shi',
#        'Nishitokyo Shi', 'Koganei Shi', 'Fussa Shi', 'Ome Shi',
#        'Hamura Shi', 'Tachikawa Shi', 'Musashino Shi',
#        'Musashimurayama Shi', 'Kunitachi Shi', 'Okutama Machi'],
#       dtype=object)

# %%
listings['neighbourhood'].value_counts()
# Out:
# Shinjuku Ku            2278
# Taito Ku               1597
# Sumida Ku              1290
# Toshima Ku             1002
# Shibuya Ku              660
# Minato Ku               409
# Setagaya Ku             394
# Ota Ku                  360
# Nakano Ku               316
# Chuo Ku                 290
# Kita Ku                 279
# Katsushika Ku           248
# Suginami Ku             241
# Koto Ku                 218
# Edogawa Ku              209
# Bunkyo Ku               208
# Arakawa Ku              198
# Itabashi Ku             181
# Shinagawa Ku            172
# Chiyoda Ku              160
# Adachi Ku                94
# Meguro Ku                69
# Nerima Ku                65
# Fuchu Shi                33
# Hachioji Shi             23
# Hino Shi                 18
# Kokubunji Shi            17
# Machida Shi              17
# Ome Shi                  14
# Chofu Shi                13
# Musashino Shi            12
# Akiruno Shi              11
# Koganei Shi              10
# Mitaka Shi               10
# Higashimurayama Shi       9
# Tama Shi                  8
# Kunitachi Shi             7
# Komae Shi                 6
# Nishitokyo Shi            6
# Tachikawa Shi             6
# Kodaira Shi               5
# Hamura Shi                4
# Musashimurayama Shi       3
# Okutama Machi             3
# Fussa Shi                 2
# Akishima Shi              2
# Name: neighbourhood, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,6))
sns.countplot(x='neighbourhood',data=listings,
              order=listings['neighbourhood'].value_counts().head(10).index,
              palette='RdPu',
              edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=50)
plt.ylabel('Count of District', weight='bold',size = 15)
plt.xlabel('District', weight='bold', size = 15)
plt.title('TOP 10 District', weight='bold' ,size = 20)
plt.grid(True)
plt.show()

# %%
import geopandas as gpd
import folium
import json

# %%
neighbor_cnt = listings['neighbourhood'].value_counts()

# %% [markdown]
# ### 도쿄 지역 에어비앤비 분포 시각화

# %%
# GeoJSON 파일 로드

geojson_path = base_path + 'neighbourhoods.geojson'
# gdf = gpd.read_file(geojson_path)
# gdf

with open(geojson_path) as f:
    geo_data = json.load(f)

# Folium 맵 생성
map = folium.Map(location=[35.6894875,139.6917064], zoom_start=11, width='80%', height='80%')

# Choropleth 레이어 추가
folium.Choropleth(
    geo_data=geo_data,
    data=neighbor_cnt,
    columns=[neighbor_cnt.index, neighbor_cnt.values],
    key_on='feature.properties.neighbourhood',
    fill_color='YlGnBu',
    fill_opacity=0.5,
    legend_name='Airbnb density scale'
).add_to(map)


# 동네 이름 표시
for feature in geo_data['features']:
    neighborhood = feature['properties']['neighbourhood']
    coordinates = feature['geometry']['coordinates'][0][0]  # 동네의 경계 좌표 가져오기
    center = [sum(coord[1] for coord in coordinates) / len(coordinates),
              sum(coord[0] for coord in coordinates) / len(coordinates)]  # 중심 좌표 계산
    icon = folium.Icon(icon='home', color='gray')  # 아이콘 선택 (여기서는 구름 아이콘)

    folium.Marker(location=center, popup=neighborhood, icon=icon).add_to(map)
    


# 타일셋 추가
folium.TileLayer('Stamen Toner').add_to(map)

# 맵 출력
map.save('map.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7c6234880b97ff253e5edecae3ac8be {
#                     position: relative;
#                     width: 80.0%;
#                     height: 80.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7c6234880b97ff253e5edecae3ac8be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7c6234880b97ff253e5edecae3ac8be = L.map(
#                 &quot;map_d7c6234880b97ff253e5edecae3ac8be&quot;,
#                 {
#                     center: [35.6894875, 139.6917064],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b29bdef55654ba5c1a4d7ce173a98d5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d7c6234880b97ff253e5edecae3ac8be);
#
#
#             var choropleth_71e6b7c611169ef6f9882c751060d0cb = L.featureGroup(
#                 {}
#             ).addTo(map_d7c6234880b97ff253e5edecae3ac8be);
#
#
#         function geo_json_1ff95e01f37427bbbf53d6ec2905aeea_styler(feature) {
#             switch(feature.properties.neighbourhood) {
#                 case &quot;Mizuho Machi&quot;: case &quot;Hinode Machi&quot;: case &quot;Higashiyamato Shi&quot;: case &quot;Miyake Mura&quot;: case &quot;Kozushima Mura&quot;: case &quot;Oshima Machi&quot;: case &quot;Niijima Mura&quot;: case &quot;Toshima Mura&quot;: case &quot;Mikurajima Mura&quot;: case &quot;Aogashima Mura&quot;: case &quot;Hachijo Machi&quot;: case &quot;Hinohara Mura&quot;: case &quot;Ogasawara Mura&quot;: case &quot;Higashikurume Shi&quot;: case &quot;Kiyose Shi&quot;: case &quot;Inagi Shi&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Minato Ku&quot;: case &quot;Setagaya Ku&quot;: case &quot;Shibuya Ku&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Shinjuku Ku&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Sumida Ku&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Taito Ku&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;Toshima Ku&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_1ff95e01f37427bbbf53d6ec2905aeea_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1ff95e01f37427bbbf53d6ec2905aeea = L.geoJson(null, {
#                 onEachFeature: geo_json_1ff95e01f37427bbbf53d6ec2905aeea_onEachFeature,
#
#                 style: geo_json_1ff95e01f37427bbbf53d6ec2905aeea_styler,
#         });
#
#         function geo_json_1ff95e01f37427bbbf53d6ec2905aeea_add (data) {
#             geo_json_1ff95e01f37427bbbf53d6ec2905aeea
#                 .addData(data)
#                 .addTo(choropleth_71e6b7c611169ef6f9882c751060d0cb);
#         }
#             geo_json_1ff95e01f37427bbbf53d6ec2905aeea_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[139.857803, 35.635799], [139.855301, 35.636868], [139.850296, 35.637665], [139.849899, 35.639267], [139.850494, 35.639999], [139.858398, 35.638134], [139.857895, 35.635864], [139.857803, 35.635799]]], [[[139.889999, 35.750801], [139.890396, 35.750401], [139.899796, 35.743732], [139.900101, 35.7356], [139.897095, 35.726665], [139.901398, 35.721466], [139.912109, 35.711266], [139.916107, 35.707733], [139.918701, 35.6978], [139.905899, 35.683731], [139.889099, 35.680599], [139.885803, 35.6768], [139.885895, 35.671131], [139.886597, 35.669868], [139.886993, 35.653866], [139.882095, 35.644001], [139.875504, 35.640533], [139.872894, 35.638535], [139.871796, 35.639332], [139.863495, 35.638401], [139.849701, 35.642666],

# %% [markdown]
# ### 에어비앤비 지역 관련 컬럼

# %%
listing_gz[['neighbourhood_cleansed','host_neighbourhood','neighborhood_overview']]
# Out:
#       neighbourhood_cleansed host_neighbourhood  \
# 0                  Sumida Ku    Sumida District
# 1                    Kita Ku      Kita District
# 2                 Shibuya Ku   Shibuya District
# 3                Setagaya Ku      Shimokitazawa
# 4                  Adachi Ku    Adachi District
# ...                      ...                ...
# 11172            Shinjuku Ku                NaN
# 11173            Shinjuku Ku                NaN
# 11174            Shinjuku Ku                NaN
# 11175            Shinjuku Ku                NaN
# 11176            Shinjuku Ku                NaN
#
#                                    neighborhood_overview
# 0                                                    NaN
# 1      We love Nishinippori because is nearer to Toky...
# 2      Hatagaya is a great neighborhood located 4 min...
# 3      The location is walkable distance to famous Sh...
# 4      There are shopping mall near Senjuohashi stati...
# ...                                                  ...
# 11172                                                NaN
# 11173                                                NaN
# 11174                                                NaN
# 11175                                                NaN
# 11176                                                NaN
#
# [11177 rows x 3 columns]

# %% [markdown]
# #### 에어비앤비 동네 후기

# %%
listing_gz['neighborhood_overview']
# Out:
# 0                                                      NaN
# 1        We love Nishinippori because is nearer to Toky...
# 2        Hatagaya is a great neighborhood located 4 min...
# 3        The location is walkable distance to famous Sh...
# 4        There are shopping mall near Senjuohashi stati...
#                                ...
# 11172                                                  NaN
# 11173                                                  NaN
# 11174                                                  NaN
# 11175                                                  NaN
# 11176                                                  NaN
# Name: neighborhood_overview, Length: 11177, dtype: object

# %%
listing_gz['neighborhood_overview'].isnull().sum() # 11177 중 3456 널값 
listing_gz['neighborhood_overview'].isnull().groupby(listing_gz['neighbourhood_cleansed']).sum().sort_values(ascending=False)
# Out:
# neighbourhood_cleansed
# Shinjuku Ku            723
# Taito Ku               492
# Sumida Ku              346
# Toshima Ku             342
# Shibuya Ku             168
# Kita Ku                118
# Minato Ku              115
# Setagaya Ku            101
# Nakano Ku               97
# Ota Ku                  94
# Arakawa Ku              85
# Katsushika Ku           85
# Chuo Ku                 84
# Edogawa Ku              82
# Shinagawa Ku            80
# Itabashi Ku             77
# Suginami Ku             58
# Bunkyo Ku               56
# Chiyoda Ku              56
# Koto Ku                 50
# Adachi Ku               34
# Fuchu Shi               26
# Nerima Ku               21
# Meguro Ku               12
# Kokubunji Shi            8
# Tachikawa Shi            6
# Ome Shi                  5
# Kunitachi Shi            3
# Hamura Shi               3
# Akiruno Shi              3
# Machida Shi              3
# Mitaka Shi               3
# Musashimurayama Shi      3
# Musashino Shi            3
# Chofu Shi                3
# Tama Shi                 2
# Komae Shi                2
# Koganei Shi              2
# Hachioji Shi             1
# Fussa Shi                1
# Hino Shi                 1
# Kodaira Shi              1
# Okutama Machi            1
# Higashimurayama Shi      0
# Nishitokyo Shi           0
# Akishima Shi             0
# Name: neighborhood_overview, dtype: int64

# %% [markdown]
# ### 도쿄 치안 데이터 전처리
# - 오시마랜드
# - 오픈데이터

# %%
import pandas as pd

# %% [markdown]
# ### 오시마랜드 데이터

# %%
oshima_yun = pd.read_csv('../../Oshimaland_data/yunyoung/selenium_tokyo_data.csv', index_col=0)
oshima_ji = pd.read_csv('../../Oshimaland_data/jieun/oshimaland_dataset_final.csv')

# %%
oshima_yun.tail()
# Out:
#     district      date                        address                content
# 298      羽村市      2005               東京都羽村市緑ヶ丘五丁目1-50  駐車スペース横の部屋で住民男性が首吊り自殺
# 299    武蔵村山市        不明                東京都羽村市羽中一丁目3-37                   告知事項
# 300      昭島市     平成24年  東京都武蔵村山市中央一丁目24-3ハウスオブブーケA 1階                   死体発見
# 301      福生市  令和2年9月7日               東京都昭島市田中町一丁目34-9                火災による死亡
# 302      福生市     2016年                  東京都福生市志茂156-1      通路から駐車場へ男性が飛び下り自殺

# %%
oshima_ji.tail()
# Out:
#                       info                 address occurred_date recorded_date
# 565                   死体発見   東京都武蔵野市西久保三丁目75都築荘101    平成28年2月23日     平成28年3月2日
# 566       5階 角部屋\r\n告知事項有り  東京都国分寺市戸倉一丁目825 PlaceK     令和4年10月6日     令和4年10月7日
# 567       6階 角部屋\r\n告知事項有り  東京都国分寺市戸倉一丁目825 PlaceK     令和4年10月6日     令和4年10月7日
# 568  206号室、506号室\r\n告知事項あり   東京都国分寺市戸倉一丁目825 プレイスK     令和4年7月30日     令和4年7月30日
# 569        606号室\r\n告知事項あり   東京都国分寺市戸倉一丁目825 プレイスK     令和4年7月30日     令和4年7月31日

# %%
oshima_yun = oshima_yun.reindex(columns=['district', 'address', 'content', 'date'])
oshima_yun.rename(columns={'content': 'info'}, inplace=True)
oshima_yun.head()
# Out:
#   district                  address            info        date
# 0      新宿区  東京都新宿区新宿三丁目22-7指田ビル地下1階            死体発見  平成24年11月5日
# 1      新宿区  東京都新宿区新宿三丁目22-7指田ビル地下1階            死体発見  平成24年11月5日
# 2      新宿区          東京都新宿区西新宿一丁目3-9          飛び降り自殺        令和4年
# 3      新宿区                      NaN             NaN         NaN
# 4      新宿区   東京都新宿区歌舞伎町一丁目27-5 中台ビル  2階サウナロイヤル 死体発見   平成20年1月5日

# %%
oshima_ji_rename = oshima_ji.reindex(columns=[ 'address', 'info', 'occurred_date'])
oshima_ji_rename.rename(columns={'occurred_date': 'date'}, inplace=True)
oshima_ji_rename.head()
# Out:
#                            address  \
# 0                 東京都新宿区歌舞伎町一丁目202
# 1  東京都新宿区歌舞伎町一丁目202アパホテル新宿歌舞伎町タワー↓
# 2                 東京都新宿区西新宿七丁目1813
# 3   東京都新宿区西新宿七丁目1713パレステュディオ新宿WEST
# 4                 東京都新宿区西新宿七丁目2231
#
#                                                 info        date
# 0                                         819号室で女性死亡  平成30年5月23日
# 1                                             飛び降り自殺   令和3年5月18日
# 2  告知事項あり\r\n※管理会社に直接確認済み\r\n\r\nハイム大成ビル 403号室\r\...        1年以内
# 3                                     １４Ｆから女性が飛び降り自殺   令和元年9月23日
# 4                                                事故死        2016

# %% [markdown]
# #### 중복데이터 확인

# %%
oshima_yun.duplicated().sum()
# Out:
# 44

# %%
oshima_yun = oshima_yun.drop_duplicates()
oshima_yun.reset_index(drop=True, inplace=True)
oshima_yun
# Out:
#     district                        address                   info        date
# 0        新宿区        東京都新宿区新宿三丁目22-7指田ビル地下1階                   死体発見  平成24年11月5日
# 1        新宿区                東京都新宿区西新宿一丁目3-9                 飛び降り自殺        令和4年
# 2        新宿区                            NaN                    NaN         NaN
# 3        新宿区         東京都新宿区歌舞伎町一丁目27-5 中台ビル         2階サウナロイヤル 死体発見   平成20年1月5日
# 4        新宿区              東京都新宿区歌舞伎町二丁目39-6                    NaN         NaN
# ..       ...                            ...                    ...         ...
# 254      羽村市               東京都羽村市緑ヶ丘五丁目1-50  駐車スペース横の部屋で住民男性が首吊り自殺        2005
# 255    武蔵村山市                東京都羽村市羽中一丁目3-37                   告知事項          不明
# 256      昭島市  東京都武蔵村山市中央一丁目24-3ハウスオブブーケA 1階                   死体発見       平成24年
# 257      福生市               東京都昭島市田中町一丁目34-9                火災による死亡    令和2年9月7日
# 258      福生市                  東京都福生市志茂156-1      通路から駐車場へ男性が飛び下り自殺       2016年
#
# [259 rows x 4 columns]

# %%
oshima_ji_rename.duplicated().sum()
# Out:
# 4

# %%
oshima_ji_rename = oshima_ji_rename.drop_duplicates()
oshima_ji_rename.reset_index(drop=True, inplace=True)
oshima_ji_rename
# Out:
#                                 address  \
# 0                      東京都新宿区歌舞伎町一丁目202
# 1       東京都新宿区歌舞伎町一丁目202アパホテル新宿歌舞伎町タワー↓
# 2                      東京都新宿区西新宿七丁目1813
# 3        東京都新宿区西新宿七丁目1713パレステュディオ新宿WEST
# 4                      東京都新宿区西新宿七丁目2231
# ..                                  ...
# 561   東京都武蔵野市緑町二丁目34都営武蔵野緑町二丁目第2アパート4号棟
# 562  東京都武蔵野市緑町二丁目64 都営武蔵野緑町2丁目第3アパート4号棟
# 563      東京都武蔵野市西久保三丁目128 アネシスヴィーゼ205号室
# 564                   東京都武蔵野市西久保三丁目1118
# 565               東京都武蔵野市西久保三丁目75都築荘101
#
#                                                   info         date
# 0                                           819号室で女性死亡   平成30年5月23日
# 1                                               飛び降り自殺    令和3年5月18日
# 2    告知事項あり\r\n※管理会社に直接確認済み\r\n\r\nハイム大成ビル 403号室\r\...         1年以内
# 3                                       １４Ｆから女性が飛び降り自殺    令和元年9月23日
# 4                                                  事故死         2016
# ..                                                 ...          ...
# 561  【青酸カリによる死者が出たそうです】\r\n4号棟の自治会役員の方の証言で、団地内で青酸カリ...           不明
# 562                                               死体発見  平成17年12月28日
# 563                                             告知事項あり           不明
# 564                                                不審死     2022年11月
# 565                                               死体発見   平成28年2月23日
#
# [566 rows x 3 columns]

# %% [markdown]
# #### 결측치 확인

# %%
oshima_yun.isnull().sum()
# Out:
# district     0
# address      6
# info        10
# date        12
# dtype: int64

# %%
oshima_yun.dropna(subset=['info'], inplace=True)
print(oshima_yun.isnull().sum())
oshima_yun
# Out:
# district    0
# address     0
# info        0
# date        4
# dtype: int64
#     district                                address                   info  \
# 0        新宿区                東京都新宿区新宿三丁目22-7指田ビル地下1階                   死体発見
# 1        新宿区                        東京都新宿区西新宿一丁目3-9                 飛び降り自殺
# 3        新宿区                 東京都新宿区歌舞伎町一丁目27-5 中台ビル         2階サウナロイヤル 死体発見
# 5        新宿区       東京都新宿区歌舞伎町一丁目20-2アパホテル新宿歌舞伎町タワー↓                 飛び降り自殺
# 6        新宿区  東京都新宿区西新宿七丁目5-9プロスペクト・アクス・ザ・タワー新宿2008                  首吊り自殺
# ..       ...                                    ...                    ...
# 254      羽村市                       東京都羽村市緑ヶ丘五丁目1-50  駐車スペース横の部屋で住民男性が首吊り自殺
# 255    武蔵村山市                        東京都羽村市羽中一丁目3-37                   告知事項
# 256      昭島市          東京都武蔵村山市中央一丁目24-3ハウスオブブーケA 1階                   死体発見
# 257      福生市                       東京都昭島市田中町一丁目34-9                火災による死亡
# 258      福生市                          東京都福生市志茂156-1      通路から駐車場へ男性が飛び下り自殺
#
#            date
# 0    平成24年11月5日
# 1          令和4年
# 3     平成20年1月5日
# 5     令和3年5月11日
# 6    平成27年9月26日
# ..          ...
# 254        2005
# 255          不明
# 256       平成24年
# 257    令和2年9月7日
# 258       2016年
#
# [249 rows x 4 columns]

# %%
oshima_ji_rename.isnull().sum()
# Out:
# address    0
# info       0
# date       3
# dtype: int64

# %% [markdown]
# #### district 컬럼 생성

# %%
jp_district_list = [
    '新宿区', '台東区', '墨田区', '豊島区', '渋谷区',
    '港区', '世田谷区', '大田区', '中野区', '中央区',
    '北区', '葛飾区', '杉並区', '江東区', '江戸川区',
    '文京区', '荒川区', '板橋区', '品川区', '千代田区',
    '足立区', '目黒区', '練馬区', '府中市', '八王子市',
    '日野市', '国分寺市', '町田市', '青梅市', '調布市',
    '武蔵野市', 'あきる野市', '三鷹市', '小金井市', '東村山市',
    '多摩市', '国立市', '狛江市', '西東京市', '立川市',
    '小平市', '羽村市', '武蔵村山市', '奥多摩町', '昭島市',
    '福生市'
]

# %%
oshima_ji_rename = oshima_ji_rename.reindex(columns = ['district', 'address', 'info', 'date'])
oshima_ji_rename
# Out:
#      district                             address  \
# 0         NaN                    東京都新宿区歌舞伎町一丁目202
# 1         NaN     東京都新宿区歌舞伎町一丁目202アパホテル新宿歌舞伎町タワー↓
# 2         NaN                    東京都新宿区西新宿七丁目1813
# 3         NaN      東京都新宿区西新宿七丁目1713パレステュディオ新宿WEST
# 4         NaN                    東京都新宿区西新宿七丁目2231
# ..        ...                                 ...
# 561       NaN   東京都武蔵野市緑町二丁目34都営武蔵野緑町二丁目第2アパート4号棟
# 562       NaN  東京都武蔵野市緑町二丁目64 都営武蔵野緑町2丁目第3アパート4号棟
# 563       NaN      東京都武蔵野市西久保三丁目128 アネシスヴィーゼ205号室
# 564       NaN                   東京都武蔵野市西久保三丁目1118
# 565       NaN               東京都武蔵野市西久保三丁目75都築荘101
#
#                                                   info         date
# 0                                           819号室で女性死亡   平成30年5月23日
# 1                                               飛び降り自殺    令和3年5月18日
# 2    告知事項あり\r\n※管理会社に直接確認済み\r\n\r\nハイム大成ビル 403号室\r\...         1年以内
# 3                                       １４Ｆから女性が飛び降り自殺    令和元年9月23日
# 4                                                  事故死         2016
# ..                                                 ...          ...
# 561  【青酸カリによる死者が出たそうです】\r\n4号棟の自治会役員の方の証言で、団地内で青酸カリ...           不明
# 562                                               死体発見  平成17年12月28日
# 563                                             告知事項あり           不明
# 564                                                不審死     2022年11月
# 565                                               死体発見   平成28年2月23日
#
# [566 rows x 4 columns]

# %%
oshima_ji_rename['district'] = oshima_ji_rename['address'].apply(lambda x: next((district for district in jp_district_list if district in x), x))
oshima_ji_rename.reindex(columns=['district', 'address', 'info', 'occurred_date'])
oshima_ji_rename
# Out:
#     district                             address  \
# 0        新宿区                    東京都新宿区歌舞伎町一丁目202
# 1        新宿区     東京都新宿区歌舞伎町一丁目202アパホテル新宿歌舞伎町タワー↓
# 2        新宿区                    東京都新宿区西新宿七丁目1813
# 3        新宿区      東京都新宿区西新宿七丁目1713パレステュディオ新宿WEST
# 4        新宿区                    東京都新宿区西新宿七丁目2231
# ..       ...                                 ...
# 561     武蔵野市   東京都武蔵野市緑町二丁目34都営武蔵野緑町二丁目第2アパート4号棟
# 562     武蔵野市  東京都武蔵野市緑町二丁目64 都営武蔵野緑町2丁目第3アパート4号棟
# 563     武蔵野市      東京都武蔵野市西久保三丁目128 アネシスヴィーゼ205号室
# 564     武蔵野市                   東京都武蔵野市西久保三丁目1118
# 565     武蔵野市               東京都武蔵野市西久保三丁目75都築荘101
#
#                                                   info         date
# 0                                           819号室で女性死亡   平成30年5月23日
# 1                                               飛び降り自殺    令和3年5月18日
# 2    告知事項あり\r\n※管理会社に直接確認済み\r\n\r\nハイム大成ビル 403号室\r\...         1年以内
# 3                                       １４Ｆから女性が飛び降り自殺    令和元年9月23日
# 4                                                  事故死         2016
# ..                                                 ...          ...
# 561  【青酸カリによる死者が出たそうです】\r\n4号棟の自治会役員の方の証言で、団地内で青酸カリ...           不明
# 562                                               死体発見  平成17年12月28日
# 563                                             告知事項あり           不明
# 564                                                不審死     2022年11月
# 565                                               死体発見   平成28年2月23日
#
# [566 rows x 4 columns]

# %%
# 공통 컬럼 
same_oshima = oshima_yun.merge(oshima_ji_rename, how='inner')
same_oshima
# Out:
#   district                                 address                     info  \
# 0      新宿区                         東京都新宿区歌舞伎町二丁目18         不動産業者より告知物件との報告有
# 1      新宿区           東京都新宿区歌舞伎町二丁目5パークネット歌舞伎町第3駐車場                     死体遺棄
# 2      新宿区                       東京都新宿区歌舞伎町二丁目9−１５                  401号、病死
# 3      文京区                   東京都文京区後楽一丁目3 東京ドームシティ  ジオポリス北側トンネル通路 ペルー人男性、病死
# 4     東村山市  東京都東村山市本町四丁目4都営東村山本町アパート9号棟4階東から5番目の部屋                     死体発見
#
#           date
# 0     2022年5月頃
# 1   平成29年2月15日
# 2        26年5月
# 3  平成20年10月15日
# 4   令和元年11月29日

# %%
# 데이터 합치기 

combined_df = pd.concat([oshima_yun, oshima_ji_rename], ignore_index=True)
combined_df
# Out:
#     district                                address  \
# 0        新宿区                東京都新宿区新宿三丁目22-7指田ビル地下1階
# 1        新宿区                        東京都新宿区西新宿一丁目3-9
# 2        新宿区                 東京都新宿区歌舞伎町一丁目27-5 中台ビル
# 3        新宿区       東京都新宿区歌舞伎町一丁目20-2アパホテル新宿歌舞伎町タワー↓
# 4        新宿区  東京都新宿区西新宿七丁目5-9プロスペクト・アクス・ザ・タワー新宿2008
# ..       ...                                    ...
# 810     武蔵野市      東京都武蔵野市緑町二丁目34都営武蔵野緑町二丁目第2アパート4号棟
# 811     武蔵野市     東京都武蔵野市緑町二丁目64 都営武蔵野緑町2丁目第3アパート4号棟
# 812     武蔵野市         東京都武蔵野市西久保三丁目128 アネシスヴィーゼ205号室
# 813     武蔵野市                      東京都武蔵野市西久保三丁目1118
# 814     武蔵野市                  東京都武蔵野市西久保三丁目75都築荘101
#
#                                                   info         date
# 0                                                 死体発見   平成24年11月5日
# 1                                               飛び降り自殺         令和4年
# 2                                       2階サウナロイヤル 死体発見    平成20年1月5日
# 3                                               飛び降り自殺    令和3年5月11日
# 4                                                首吊り自殺   平成27年9月26日
# ..                                                 ...          ...
# 810  【青酸カリによる死者が出たそうです】\r\n4号棟の自治会役員の方の証言で、団地内で青酸カリ...           不明
# 811                                               死体発見  平成17年12月28日
# 812                                             告知事項あり           不明
# 813                                                不審死     2022年11月
# 814                                               死体発見   平成28年2月23日
#
# [815 rows x 4 columns]

# %% [markdown]
# ### 도쿄 Open Data

# %% [markdown]
# ```
# '罪名': 범죄의 종류 또는 범죄명을 나타냅니다.
# '手口': 범죄의 접근 방식 또는 행동을 나타냅니다.
# '管轄警察署（発生地）': 범죄가 발생한 지역의 관할 경찰서를 나타냅니다.
# '管轄交番・駐在所（発生地）': 범죄가 발생한 지역의 관할 파출소 또는 장애소를 나타냅니다.
# '市区町村コード（発生地）': 범죄가 발생한 지역의 시, 구, 동 등을 식별하는 코드를 나타냅니다.
# '都道府県（発生地）': 범죄가 발생한 지역의 도 또는 특별시를 나타냅니다.
# '市区町村（発生地）': 범죄가 발생한 지역의 시, 구, 동 등을 나타냅니다.
# '町丁目（発生地）': 범죄가 발생한 지역의 동 등을 좀 더 구체적으로 나타냅니다.
# '発生年月日（始期）': 범죄가 발생한 날짜를 나타냅니다.
# '発生時（始期）': 범죄가 발생한 시간을 나타냅니다.
# '発生場所の属性': 범죄가 발생한 장소의 특성을 나타냅니다.
# '現金以外の主な被害品': 현금 이외의 주요 피해 물품을 나타냅니다.
# '被害者の性別': 피해자의 성별을 나타냅니다.
# '被害者の年齢': 피해자의 나이를 나타냅니다.
# '現金被害の有無': 현금 피해의 여부를 나타냅니다.
# '施錠関係': 잠금 관련 정보를 나타냅니다.
# '盗難防止装置の有無': 도난 방지 장치의 여부를 나타냅니다.
# '被害者の職業': 피해자의 직업을 나타냅니다.
# '発生場所': 범죄가 발생한 장소를 나타냅니다.
# '発生場所の詳細': 범죄가 발생한 장소에 대한 자세한 정보를 나타냅니다.
# ```

# %%
open_data = pd.read_csv('../../Tokyo_OpenData/Integration of downloaded CSV files/TokyoCrime.csv', encoding='SHIFT_JIS', index_col=0)
open_data.tail()
# Out:
# C:\Users\YUN\AppData\Local\Temp\ipykernel_19180\3614512242.py:1: DtypeWarning: Columns (11,12,13,15,17,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   open_data = pd.read_csv('../../Tokyo_OpenData/Integration of downloaded CSV files/TokyoCrime.csv', encoding='SHIFT_JIS', index_col=0)
#         罪名    手口 管轄警察署（発生地） 管轄交番・駐在所（発生地）  市区町村コード（発生地） 都道府県（発生地） 市区町村（発生地）  \
# 132315  窃盗  自転車盗         小平       鷹の台駅前交番      132110.0       東京都       小平市
# 132316  窃盗  自転車盗         小平       鷹の台駅前交番      132110.0       東京都       小平市
# 132317  窃盗  自転車盗         小平       鷹の台駅前交番      132110.0       東京都       小平市
# 132318  窃盗  自転車盗         小平       鷹の台駅前交番      132110.0       東京都       小平市
# 132319  窃盗  自転車盗        八丈島         三根駐在所           NaN       東京都    八丈島八丈町
#
#        町丁目（発生地）   発生年月日（始期） 発生時（始期） 発生場所の属性 現金以外の主な被害品 被害者の性別 被害者の年齢 現金被害の有無  \
# 132315   津田町２丁目   2021/3/17      21     NaN        NaN    NaN   50歳代     NaN
# 132316   津田町２丁目   2021/9/30      13     NaN        NaN    NaN   20歳代     NaN
# 132317   津田町２丁目  2021/10/15      16     NaN        NaN    NaN   40歳代     NaN
# 132318   津田町３丁目  2021/12/18      15     NaN        NaN    NaN   20歳代     NaN
# 132319       三根   2021/5/31       5     NaN        NaN    NaN   40歳代     NaN
#
#         施錠関係 盗難防止装置の有無 被害者の職業                 発生場所 発生場所の詳細
# 132315  施錠した       NaN    その他                  道路上     その他
# 132316  施錠せず       NaN    大学生  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場
# 132317  施錠せず       NaN    その他  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場
# 132318  施錠した       NaN    その他  その他の住宅（３階建て以下共同住宅等）  駐車（輪）場
# 132319  施錠せず       NaN    その他                一戸建住宅     その他

# %%
column_mapping = {
    '罪名': 'Crime',
    '手口': 'Method',
    '管轄警察署（発生地）': 'Jurisdiction Police Station',
    '管轄交番・駐在所（発生地）': 'Jurisdiction Police Box',
    '市区町村コード（発生地）': 'Municipal Code',
    '都道府県（発生地）': 'Prefecture',
    '市区町村（発生地）': 'Region',
    '町丁目（発生地）': 'Address',
    '発生年月日（始期）': 'Date',
    '発生時（始期）': 'Time',
    '発生場所の属性': 'Location Attribute',
    '現金以外の主な被害品': 'Main Stolen Items (Excluding Cash)',
    '被害者の性別': 'Victim Gender',
    '被害者の年齢': 'Victim Age',
    '現金被害の有無': 'Cash Loss',
    '施錠関係': 'Locking Status',
    '盗難防止装置の有無': 'Anti-Theft Device',
    '被害者の職業': 'Victim Occupation',
    '発生場所': 'Location of Occurrence',
    '発生場所の詳細': 'Detailed Location of Occurrence'
}

# %%
open_data.rename(columns=column_mapping, inplace=True)
open_data.head()
# Out:
#   Crime Method Jurisdiction Police Station Jurisdiction Police Box  \
# 0    窃盗  部品ねらい                          中央                    本町交番
# 1    窃盗  部品ねらい                          中央                   日本橋交番
# 2    窃盗  部品ねらい                          中央                   日本橋交番
# 3    窃盗  部品ねらい                          中央                  八重洲通交番
# 4    窃盗  部品ねらい                          中央                  八重洲通交番
#
#    Municipal Code Prefecture Region    Address        Date Time  \
# 0        131024.0        東京都    中央区  日本橋本石町４丁目  2018-03-25   13
# 1        131024.0        東京都    中央区     日本橋１丁目  2018-01-22   09
# 2        131024.0        東京都    中央区   日本橋室町１丁目  2018-05-01   15
# 3        131024.0        東京都    中央区     八重洲１丁目  2017-12-20   不明
# 4        131024.0        東京都    中央区     八重洲２丁目  2018-11-09   11
#
#   Location Attribute Main Stolen Items (Excluding Cash) Victim Gender  \
# 0                その他                           ナンバープレート           NaN
# 1                道路上                                その他           NaN
# 2                道路上                                その他           NaN
# 3                道路上                           ナンバープレート           NaN
# 4             駐車（輪）場                                その他           NaN
#
#   Victim Age Cash Loss Locking Status Anti-Theft Device Victim Occupation  \
# 0        NaN       NaN            NaN               NaN               NaN
# 1        NaN       NaN            NaN               NaN               NaN
# 2        NaN       NaN            NaN               NaN               NaN
# 3        NaN       NaN            NaN               NaN               NaN
# 4        NaN       NaN            NaN               NaN               NaN
#
#   Location of Occurrence Detailed Location of Occurrence
# 0                    NaN                             NaN
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                             NaN

# %% [markdown]
# #### 범죄 유형 컬럼
# '罪名': 범죄의 종류 또는 범죄명을 나타냅니다.
#
# '手口': 범죄의 접근 방식 또는 행동을 나타냅니다.

# %%
open_data['Crime'].unique() # 절도
# Out:
# array(['窃盗'], dtype=object)

# %%
# ['부품 겨냥', '날치기', '오토바이 도둑질', '차상 노리기', '자동판매기 노리기', '자동차 도둑질', '자전거 도둑질']
open_data['Method'].unique()
# Out:
# array(['部品ねらい', 'ひったくり', 'オートバイ盗', '車上ねらい', '自動販売機ねらい', '自動車盗', '自転車盗'],
#       dtype=object)

# %% [markdown]
# #### 범죄 지역 컬럼
#
# 管轄警察署（発生地）': 범죄가 발생한 지역의 관할 경찰서를 나타냅니다.
#
# '管轄交番・駐在所（発生地）': 범죄가 발생한 지역의 관할 파출소 또는 장애소를 나타냅니다.
#
# '市区町村コード（発生地）': 범죄가 발생한 지역의 시, 구, 동 등을 식별하는 코드를 나타냅니다.
#
# '都道府県（発生地）': 범죄가 발생한 지역의 도 또는 특별시를 나타냅니다.
#
# '市区町村（発生地）': 범죄가 발생한 지역의 시, 구, 동 등을 나타냅니다.
#
# '町丁目（発生地）': 범죄가 발생한 지역의 동 등을 좀 더 구체적으로 나타냅니다.

# %%
# 관할 경찰서
open_data['Jurisdiction Police Station'].unique()
# Out:
# array(['中央', '深川', '麹町', '丸の内', '神田', '万世橋', '久松', '築地', '月島', '愛宕', '三田',
#        '高輪', '麻布', '赤坂', '東京湾岸', '品川', '大井', '大崎', '荏原', '大森', '田園調布',
#        '蒲田', '池上', '東京空港', '世田谷', '北沢', '玉川', '成城', '目黒', '碑文谷', '渋谷',
#        '原宿', '代々木', '牛込', '新宿', '戸塚', '四谷', '中野', '野方', '杉並', '高井戸', '荻窪',
#        '富坂', '大塚', '本富士', '駒込', '巣鴨', '池袋', '目白', '滝野川', '王子', '赤羽', '板橋',
#        '志村', '練馬', '石神井', '高島平', '光が丘', '上野', '下谷', '浅草', '蔵前', '尾久',
#        '南千住', '荒川', '千住', '西新井', '綾瀬', '竹の塚', '城東', '本所', '向島', '亀有',
#        '葛飾', '小松川', '小岩', '葛西', '南大沢', '高尾', '多摩中央', '東大和', '青梅', '五日市',
#        '福生', '八王子', '町田', '日野', '昭島', '立川', '府中', '小金井', '田無', '東村山',
#        '武蔵野', '三鷹', '調布', '小平', '三宅島', '新島', '八丈島', '小笠原', '大島'],
#       dtype=object)

# %% [markdown]
# 관할 파출소 또는 장애소
#
# 本町交番 - 혼마치 코반
#
# 日本橋交番 - 닛폰바시 코반
#
# 八重洲通交番 - 야에스도오리 코반
#
# 高橋交番 - 다카하시 코반
#
# 森下交番 - 모리시타 코반
#
# 住吉交番 - 스미요시 코반
#
# 東陽交番 - 토요 코반
#
# 門前仲町交番 - 몬젠나카초 코반
#
# 千田交番 - 센다 코반
#
# 豊洲交番 - 토요스 코반
#
# 現代美術館前交番 - 현대 미술관 앞 코반

# %%
# 관할 파출소 또는 장애소
police_box = open_data['Jurisdiction Police Box'].unique() 
print(len(police_box))
police_box[:30]
# Out:
# 1047
# array(['本町交番', '日本橋交番', '八重洲通交番', '高橋交番', '森下交番', '住吉交番', '東陽交番',
#        '門前仲町交番', '千田交番', '豊洲交番', '現代美術館前交番', '枝川交番', '市ケ谷見付交番', '内幸町交番',
#        '日比谷公園前交番', '有楽町駅前交番', '東京駅前交番', '八重洲口交番', '和田倉門外交番', '司町交番',
#        '神保町交番', '神田駅交番', '岩本町交番', '美倉橋交番', '秋葉原交番', '水天宮前交番', '浜町交番',
#        '東日本橋交番', '銀座一丁目交番', '中央市場交番'], dtype=object)

# %% [markdown]
# 코드 정보 :	https://www.j-lis.go.jp/spd/code-address/kantou/cms_13414181.html

# %%
# 시, 구, 동 등을 식별하는 코드
# 일반적인 postal code (Adachi : 〒120-0015 ) 는 아님 
open_data['Municipal Code'].unique()
# Out:
# array([131024., 131083., 131016., 131032., 131091., 131113.,     nan,
#        131121., 131105., 131130., 131041., 131075., 131148., 131156.,
#        131059., 131164., 131172., 131199., 131202., 131067., 131181.,
#        131211., 131229., 131237., 132012., 132098., 132241., 132250.,
#        132209., 132233., 132055., 132284., 132187., 133035., 132276.,
#        132128., 132071., 132152., 132021., 132063., 132101., 132144.,
#        132292., 132225., 132136., 132217., 132039., 132047., 132080.,
#        132195., 132110., 133647., 133051., 133086., 134015., 133612.,
#        133639., 134210., 133078.])

# %%
#범죄가 발생한 지역의 도 또는 특별시를 나타냅니다.
open_data['Prefecture'].unique() # 도쿄도
# Out:
# array(['東京都', nan], dtype=object)

# %% [markdown]
# 닛폰바시못이치 4-초메
#
# 닛폰바시 1-초메
#
# 닛폰바시무로마치 1-초메
#
# 야에스도오리 1-초메
#
# 야에스도오리 2-초메
#
# 신가와 2-초메
#
# 토쿠와 1-초메
#
#  모우리 1-초메

# %%
# 범죄가 발생한 지역의 동 등을 좀 더 구체적으로 나타냅니다.
# 오시마랜드 검색시 fire 객체 정보 미미함  
detail_address = open_data['Address'].unique() 
print(len(detail_address))
detail_address[:30]
# Out:
# 4783
# array(['日本橋本石町４丁目', '日本橋１丁目', '日本橋室町１丁目', '八重洲１丁目', '八重洲２丁目', '新川２丁目',
#        '常盤１丁目', '毛利１丁目', '塩浜２丁目', '東陽３丁目', '東陽４丁目', '門前仲町２丁目', '千石３丁目',
#        '豊洲２丁目', '豊洲４丁目', '豊洲５丁目', '平野３丁目', '潮見２丁目', '古石場２丁目', '六番町',
#        '内幸町１丁目', '内幸町２丁目', '日比谷公園', '有楽町１丁目', '有楽町２丁目', '丸の内１丁目',
#        '大手町１丁目', '神田多町２丁目', nan, '神田神保町１丁目'], dtype=object)

# %% [markdown]
# #### 범죄 날짜 컬럼

# %%
# 범죄가 발생한 날짜를 나타냅니다.
open_data['Date'].unique()
# Out:
# array(['2018-03-25', '2018-01-22', '2018-05-01', ..., '2020/5/8',
#        '2020/7/28', '2020/6/10'], dtype=object)

# %%
# 범죄가 발생한 시간을 나타냅니다.
open_data['Time'].unique()
# Out:
# array(['13', '09', '15', '不明', '11', '12', '19', '21', '08', '16', '17',
#        '23', '18', '20', '06', '22', '07', '14', '05', '10', '02', '00',
#        '01', '04', '03', '0', '9', '3', '5', '2', '1', '4', '8', '6', '7'],
#       dtype=object)

# %% [markdown]
# #### 범죄 특성 컬럼

# %%
# 범죄가 발생한 장소의 특성을 나타냅니다.
open_data['Location Attribute' ].unique()
# Out:
# array(['その他', '道路上', '駐車（輪）場', '４階建て以上共同住宅', '一戸建住宅',
#        'その他の住宅（３階建て以下共同住宅等）', nan], dtype=object)

# %%
# 잠금 관련 정보를 나타냅니다.
# 열쇠 있음', '열쇠 없음', '잠금했다', '잠금하지 않음'
open_data['Locking Status' ].unique()
# Out:
# array([nan, 'キーあり', 'キーなし', '施錠した', '施錠せず'], dtype=object)

# %%
# 도난 방지 장치의 여부를 나타냅니다.
open_data['Anti-Theft Device' ].unique()
# Out:
# array([nan, 'なし', 'あり'], dtype=object)

# %%
# 범죄가 발생한 장소에 대한 자세한 정보를 나타냅니다.
# '주차장', '기타'
open_data['Detailed Location of Occurrence' ].unique()
# Out:
# array([nan, '駐車（輪）場', 'その他'], dtype=object)

# %% [markdown]
# ### EDA
#
# ####  에어비앤비 추천시 필요한 컬럼
#
# - Crime : ['부품 겨냥', '날치기', '오토바이 도둑질', '차상 노리기', '자동판매기 노리기', '자동차 도둑질', '자전거 도둑질']
#
# -  Address : 자세한 범죄 발생 주소
# - Municipal Code : 지역 코드 :
#
# - Date : 범죄 발생 날짜

# %%
open_data_selecct = open_data.copy()
open_data_selecct = open_data_selecct[['Date', 'Method', 'Address', 'Municipal Code']]
open_data_selecct.rename(columns={'Date' : 'date', 'Method' : 'info', 'Address': 'address', 'Municipal Code' : 'code'}, inplace=True)
open_data_selecct
# Out:
#               date   info    address      code
# 0       2018-03-25  部品ねらい  日本橋本石町４丁目  131024.0
# 1       2018-01-22  部品ねらい     日本橋１丁目  131024.0
# 2       2018-05-01  部品ねらい   日本橋室町１丁目  131024.0
# 3       2017-12-20  部品ねらい     八重洲１丁目  131024.0
# 4       2018-11-09  部品ねらい     八重洲２丁目  131024.0
# ...            ...    ...        ...       ...
# 132315   2021/3/17   自転車盗     津田町２丁目  132110.0
# 132316   2021/9/30   自転車盗     津田町２丁目  132110.0
# 132317  2021/10/15   自転車盗     津田町２丁目  132110.0
# 132318  2021/12/18   自転車盗     津田町３丁目  132110.0
# 132319   2021/5/31   自転車盗         三根       NaN
#
# [132320 rows x 4 columns]

# %%
open_data_selecct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132320 entries, 0 to 132319
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     132320 non-null  object
#  1   info     132320 non-null  object
#  2   address  132247 non-null  object
#  3   code     132281 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 5.0+ MB

# %%
open_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132320 entries, 0 to 132319
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   罪名             132320 non-null  object
#  1   手口             132320 non-null  object
#  2   管轄警察署（発生地）     132320 non-null  object
#  3   管轄交番・駐在所（発生地）  132240 non-null  object
#  4   市区町村コード（発生地）   132281 non-null  float64
#  5   都道府県（発生地）      132288 non-null  object
#  6   市区町村（発生地）      132288 non-null  object
#  7   町丁目（発生地）       132247 non-null  object
#  8   発生年月日（始期）      132320 non-null  object
#  9   発生時（始期）        132320 non-null  object
#  10  発生場所の属性        80634 non-null   object
#  11  現金以外の主な被害品     11039 non-null   object
#  12  被害者の性別         683 non-null     object
#  13  被害者の年齢         110764 non-null  object
#  14  現金被害の有無        11200 non-null   object
#  15  施錠関係           124069 non-null  object
#  16  盗難防止装置の有無      4906 non-null    object
#  17  被害者の職業         110081 non-null  object
#  18  発生場所           51686 non-null   object
#  19  発生場所の詳細        51524 non-null   object
# dtypes: float64(1), object(19)
# memory usage: 21.2+ MB

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# 웹 페이지 URL
url = 'https://www.j-lis.go.jp/spd/code-address/kantou/cms_13414181.html'

chrome_option = webdriver.ChromeOptions()
driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_option)
driver.get(url)

# 웹 페이지 가져오기
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table_data = []
table = soup.find('table', class_='tbl')


rows = table.find_all('tr')

# 헤더 정보 가져오기
header_row = rows[0]
headers = [header.text.strip() for header in header_row.find_all('th')]

# 테이블 데이터 가져오기
for row in rows[1:]:
    data = [cell.text.strip() for cell in row.find_all('td')]
    table_data.append(data)

# 결과 출력
for row_data in table_data:
    print(row_data)


driver.quit()
# Out:
# ['131016', '千代田区', 'ちよだく', '102-8688', '千代田区九段南1-2-1', '03-3264-2111']
# ['131024', '中央区', 'ちゅうおうく', '104-8404', '中央区築地1-1-1', '03-3543-0211']
# ['131032', '港区', 'みなとく', '105-8511', '港区芝公園1-5-25', '03-3578-2111']
# ['131041', '新宿区', 'しんじゅくく', '160-8484', '新宿区歌舞伎町1-4-1', '03-3209-1111']
# ['131059', '文京区', 'ぶんきょうく', '112-8555', '文京区春日1-16-21', '03-3812-7111']
# ['131067', '台東区', 'たいとうく', '110-8615', '台東区東上野4-5-6', '03-5246-1111']
# ['131075', '墨田区', 'すみだく', '130-8640', '墨田区吾妻橋1-23-20', '03-5608-1111']
# ['131083', '江東区', 'こうとうく', '135-8383', '江東区東陽4-11-28', '03-3647-9111']
# ['131091', '品川区', 'しながわく', '140-8715', '品川区広町2-1-36', '03-3777-1111']
# ['131105', '目黒区', 'めぐろく', '153-8573', '目黒区上目黒2-19-15', '03-3715-1111']
# ['131113', '大田区', 'おおたく', '144-8621', '大田区蒲田5-13-14', '03-5744-1111']
# ['131121', '世田谷区', 'せたがやく', '154-8504', '世田谷区世田谷4-21-27', '03-5432-1111']
# ['131130', '渋谷区', 'しぶやく', '150-8010', '渋谷区宇田川町1-1', '03-3463-1211']
# ['131148', '中野区', 'なかのく', '164-8501', '中野区中野4-8-1', '03-3389-1111']
# ['131156', '杉並区', 'すぎなみく', '166-8570', '杉並区阿佐谷南1-15-1', '03-3312-2111']
# ['131164', '豊島区', 'としまく', '171-8422', '豊島区南池袋2-45-1', '03-3981-1111']
# ['131172', '北区', 'きたく', '114-8508', '北区王子本町1-15-22', '03-3908-1111']
# ['131181', '荒川区', 'あらかわく', '116-8501', '荒川区荒川2-2-3', '03-3802-3111']
# ['131199', '板橋区', 'いたばしく', '173-8501', '板橋区板橋2-66-1', '03-3964-1111']
# ['131202', '練馬区', 'ねりまく', '176-8501', '練馬区豊玉北6-12-1', '03-3993-1111']
# ['131211', '足立区', 'あだちく', '120-8510', '足立区中央本町1-17-1', '03-3880-5111']
# ['131229', '葛飾区', 'かつしかく', '124-8555', '葛飾区立石5-13-1', '03-3695-1111']
# ['131237', '江戸川区', 'えどがわく', '132-8501', '江戸川区中央1-4-1', '03-3652-1151']
# ['132012', '八王子市', 'はちおうじし', '192-8501', '八王子市元本郷町3-24-1', '042-626-3111']
# ['132021', '立川市', 'たちかわし', '190-8666', '立川市泉町1156-9', '042-523-2111']
# ['132039', '武蔵野市', 'むさしのし', '180-8777', '武蔵野市緑町2-2-28', '0422-51-5131']
# ['132047', '三鷹市', 'みたかし', '181-8555', '三鷹市野崎1-1-1', '0422-45-1151']
# ['132055', '青梅市', 'おうめし', '198-8701', '青梅市東青梅1-11-1', '0428-22-1111']
# ['132063', '府中市', 'ふちゅうし', '183-8703', '府中市宮西町2-24', '042-364-4111']
# ['132071', '昭島市', 'あきしまし', '196-8511', '昭島市田中町1-17-1', '042-544-5111']
# ['132080', '調布市', 'ちょうふし', '182-8511', '調布市小島町2-35-1', '042-481-7111']
# ['132098', '町田市', 'まちだし', '194-8520', '町田市森野2-2-22', '042-722-3111']
# ['132101', '小金井市', 'こがねいし', '184-8504', '小金井市本町6-6-3', '042-383-1111']
# ['132110', '小平市', 'こだいらし', '187-8701', '小平市小川町2-1333', '042-341-1211']
# ['132128', '日野市', 'ひのし', '191-0016', '日野市神明1-12-1', '042-585-1111']
# ['132136', '東村山市', 'ひがしむらやまし', '189-8501', '東村山市本町1-2-3', '042-393-5111']
# ['132144', '国分寺市', 'こくぶんじし', '185-8501', '国分寺市戸倉1-6-1', '042-325-0111']
# ['132152', '国立市', 'くにたちし', '186-8501', '国立市富士見台2-47-1', '042-576-2111']
# ['132187', '福生市', 'ふっさし', '197-8501', '福生市本町5', '042-551-1511']
# ['132195', '狛江市', 'こまえし', '201-8585', '狛江市和泉本町1-1-5', '03-3430-1111']
# ['132209', '東大和市', 'ひがしやまとし', '207-8585', '東大和市中央3-930', '042-563-2111']
# ['132217', '清瀬市', 'きよせし', '204-8511', '清瀬市中里5-842', '042-492-5111']
# ['132225', '東久留米市', 'ひがしくるめし', '203-8555', '東久留米市本町3-3-1', '042-470-7777']
# ['132233', '武蔵村山市', 'むさしむらやまし', '208-8501', '武蔵村山市本町1-1-1', '042-565-1111']
# ['132241', '多摩市', 'たまし', '206-8666', '多摩市関戸6-12-1', '042-375-8111']
# ['132250', '稲城市', 'いなぎし', '206-8601', '稲城市東長沼2111', '042-378-2111']
# ['132276', '羽村市', 'はむらし', '205-8601', '羽村市緑ヶ丘5-2-1', '042-555-1111']
# ['132284', 'あきる野市', 'あきるのし', '197-0814', 'あきる野市二宮350', '042-558-1111']
# ['132292', '西東京市', 'にしとうきょうし', '188-8666', '西東京市南町5-6-13', '042-464-1311']
# ['133035', '瑞穂町', 'みずほまち', '190-1292', '西多摩郡瑞穂町大字箱根ヶ崎2335', '042-557-0501']
# ['133051', '日の出町', 'ひのでまち', '190-0192', '西多摩郡日の出町平井2780', '042-597-0511']
# ['133078', '檜原村', 'ひのはらむら', '190-0212', '西多摩郡檜原村467-1', '042-598-1011']
# ['133086', '奥多摩町', 'おくたままち', '198-0212', '西多摩郡奥多摩町氷川215-6', '0428-83-2111']
# ['133612', '大島町', 'おおしままち', '100-0101', '大島町元町1-1-14', '04992-2-1443']
# ['133621', '利島村', 'としまむら', '100-0301', '利島村248', '04992-9-0011']
# ['133639', '新島村', 'にいじまむら', '100-0402', '新島村本村1-1-1', '04992-5-0240']
# ['133647', '神津島村', 'こうづしまむら', '100-0601', '神津島村904', '04992-8-0011']
# ['133817', '三宅村', 'みやけむら', '100-1212', '三宅島三宅村阿古497', '04994-5-0981']
# ['133825', '御蔵島村', 'みくらじまむら', '100-1301', '御蔵島村字入かねが沢', '04994-8-2121']
# ['134015', '八丈町', 'はちじょうまち', '100-1498', '八丈島八丈町大賀郷2551-2', '04996-2-1121']
# ['134023', '青ヶ島村', 'あおがしまむら', '100-1701', '青ヶ島村無番地', '04996-9-0111']
# ['134210', '小笠原村', 'おがさわらむら', '100-2101', '小笠原村父島字西町', '04998-2-3111']
